# %% [markdown]
# <a href="https://colab.research.google.com/github/TristanThomsen/ThinkPython2026/blob/main/roster_py/roster_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###### ROSTER TEAM PROGRAM ######
    # Need to be able to view the roster
    # Need to be able to add a player to the roster
    # Need to be able to remove a player from the roster
    # Need to be able to "Quit!" when inputed (user input's "Quit" to leave menu)

###### IMPORT STATEMENTS ######
# None
###### FUNCTION DEFINITONS ######

# 1. View the Roster of players.
def view_roster(roster):
  print(roster)
# 2. Add players to the roster.
def add_player(roster):

# 3. Remove the players from the roster.

# 4. Edit a Players Name on the roster.

# 5. Is on Roster to confirm that player is on it.

# 6. Exit Roster.

###### PROGRAM LOGIC ######

# Create the empty roster
  roster = []

# While True Loop
while True:
  # Roster Menu appears with a list to choose from.
  user_option = int(input("""
          Welcome to the Roster!
  Please select one of the following options:

        1. See the roster
        2. Add a player to the roster
        3. Remove a player from the roster
        4. Edit the roster
        5. Quit

        """))
# 1. User can call the list of players.
  if user_option == 1:
  # Call the roster list function
    print(roster)

# 2. User can add a player to the roster.
  if user_option == 2:
    # Who does the user want to add to the roster
    player_name = input("What is the name of the player you would like to add to the roster? ")
    roster.append(player_name)
    print(roster)

  # Call the Add Player function

# 3. User can remove a selected player from the roster.
  # Who does the user want to remove from the roster
  # Call the Remove Player function

# 4. User can edit the names on the roster.
  # Call the Roster Function
  # The User chooses who he wants to edit
  # Ask the user for the new input on the roster
  # Call the Edit Roster Function

# 5. User can input a name to determine if they are on the roster.
  # Inputs the name of the player and replies True or False (Boolean)

# 6. User input's "Quit" to close the roster menu.
  if user_option == 5:
    print("Thanks for viewing the roster! Goodbye!")
    break
  # Ends the program and closes out the roster.
# Out:
#           Welcome to the Roster!
#   Please select one of the following options:
#
#         1. See the roster
#         2. Add a player to the roster
#         3. Remove a player from the roster
#         4. Edit the roster
#         5. Quit
#
#         1
# []
#
#           Welcome to the Roster!
#   Please select one of the following options:
#
#         1. See the roster
#         2. Add a player to the roster
#         3. Remove a player from the roster
#         4. Edit the roster
#         5. Quit
#
#         2
# What is the name of the player you would like to add to the roster? Adam
# ['Adam']
#
#           Welcome to the Roster!
#   Please select one of the following options:
#
#         1. See the roster
#         2. Add a player to the roster
#         3. Remove a player from the roster
#         4. Edit the roster
#         5. Quit
#
#         1
# ['Adam']
#
#           Welcome to the Roster!
#   Please select one of the following options:
#
#         1. See the roster
#         2. Add a player to the roster
#         3. Remove a player from the roster
#         4. Edit the roster
#         5. Quit
#
#         2
# What is the name of the player you would like to add to the roster? Josh
# ['Adam', 'Josh']
#
#           Welcome to the Roster!
#   Please select one of the following options:
#
#         1. See the roster
#         2. Add a player to the roster
#         3. Remove a player from the roster
#         4. Edit the roster
#         5. Quit
#
#         1
# ['Adam', 'Josh']
#
#           Welcome to the Roster!
#   Please select one of the following options:
#
#         1. See the roster
#         2. Add a player to the roster
#         3. Remove a player from the roster
#         4. Edit the roster
#         5. Quit
#
#         5
# Thanks for viewing the roster! Goodbye!
