# %% [markdown]
# <a href="https://colab.research.google.com/github/TristanThomsen/ThinkPython2026/blob/main/Week5/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
# 2. Logic: if age <= 12 or Age >= 65, price = 8. Otherwise, price = 12.
# 3. Logic: if hour < 17, subtract 2 from the price.
# 4. Print the final price.

# PROGRAM LOGIC
# 1. input() for age (int)
# 2. input() for movie hour (int)
# 3. Call calculate_ticket()
