# %% [markdown]
# <a href="https://colab.research.google.com/github/TristanThomsen/ThinkPython2026/blob/main/Expense_Tracker/Expense_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#### IMPORT STATEMENTS ####
import pandas as pd
from datetime import datetime
#### FUNCTION DEFINITIONS ####
# Make the empty list for the transactions.
transactions = []
# Add a transaction entry in (The record for the Date, Amount, Category, Vendor, and Description).
def add_transactions(date_str, amount, category, vendor, description):
# Create a dictionary for the new transaction
    new_transaction = {
        "Date": date_str,
        "Amount": amount,
        "Category": category,
        "Vendor": vendor,
        "Description": description
    }
# Add the new transaction to the global list of transactions
    transactions.append(new_transaction)
    print(f"Transaction added: {date_str}, {amount}, {category}, {vendor}, {description}")
    return transactions
# Add the new row to the list of transactions
    transactions_list.append(new_row)
    print(f"Transaction added: {date_str}, {amount}, {category}, {vendor}, {description}")
    return transactions
# Filtering Transactions for different categories.



#### PROGRAM LOGIC ####
# Ask the user what they would like to pick from on the list (1. Add New Expense, 2. Get Totals, 3. Exit)
while True:
  print("What would like to do?")
  print("1. Add New Expense")
  print("2. Get Totals")
  print("3. Exit")
  user_input = input("Your Choice: ").upper()
  if user_input == "3":
    print("Have a great day! Enjoy your Expenses")
    break
  # If the User selects "Add New Expense" call the "add_transactions" Function
  elif user_input == "1":
    date_str = input("Enter the date (YYYY-MM-DD): ")
    amount = float(input("Enter the amount: ").replace('$', ''))
    category = input("Enter the category: ")
    vendor = input("Enter the vendor: ")
    description = input("Enter a description: ")
    add_transactions(date_str, amount, category, vendor, description)
    print("Transaction Added")
    print(transactions)
  # If the user puts in the "Get Totals" Option, put them into a sub-menu (A: All Expenses, C:Filter by Category, V: Filter by Vendor)
  elif user_input == "2":
    print("What would you like to filter by?")
    print("A. All Expenses")
    print("C. Filter by Category")
    print("V. Filter by Vendor")
    sub_user_input = input("Your Choice: ").upper()
  # If the user inputs "A" into the sub menu, Show all Transactions
    if sub_user_input == "A":
      print("All Expenses")
      print(transactions)
  # If the user inputs "C" into the sub menu, to filter by "Category"
    elif sub_user_input == "C":
      category = input("Enter the category: ")
      filtered_transactions = [transaction for transaction in transactions if transaction["Category"] == category]
      print(f"Filtered Transactions for Category: {category}")
      print(filtered_transactions)
  # If the user inputs "V" to filter by "Vendor"
    elif sub_user_input == "V":
      vendor = input("Enter the vendor: ")
      filtered_transactions = [transaction for transaction in transactions if transaction["Vendor"] == vendor]
      print(f"Filtered Transactions for Vendor: {vendor}")
      print(filtered_transactions)
# Wrap this in a while loop until they type Exit.
# Out:
# What would like to do?
# 1. Add New Expense
# 2. Get Totals
# 3. Exit
# Your Choice: 1
# Enter the date (YYYY-MM-DD): 2026-05-24
# Enter the amount: $35.45
# Enter the category: Misc
# Enter the vendor: Autozone
# Enter a description: Oil/Oil Filter
# Transaction added: 2026-05-24, 35.45, Misc, Autozone, Oil/Oil Filter
# Transaction Added
# [{'Date': '2026-05-24', 'Amount': 35.45, 'Category': 'Misc', 'Vendor': 'Autozone', 'Description': 'Oil/Oil Filter'}]
# What would like to do?
# 1. Add New Expense
# 2. Get Totals
# 3. Exit
# Your Choice: 1
# Enter the date (YYYY-MM-DD): 2026-03-19
# Enter the amount: 63.23
# Enter the category: Misc
# Enter the vendor: Steam
# Enter a description: Game
# Transaction added: 2026-03-19, 63.23, Misc, Steam, Game
# Transaction Added
# [{'Date': '2026-05-24', 'Amount': 35.45, 'Category': 'Misc', 'Vendor': 'Autozone', 'Description': 'Oil/Oil Filter'}, {'Date': '2026-03-19', 'Amount': 63.23, 'Category': 'Misc', 'Vendor': 'Steam', 'Description': 'Game'}]
# ...
