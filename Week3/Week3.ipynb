# %% [markdown]
# <a href="https://colab.research.google.com/github/TristanThomsen/ThinkPython2026/blob/main/Week3/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# Function Definitions

# Program Logic
# Assign values to variables: name, goal, birth_year, current_year
name = "Tristan Thomsen"
goal = "I am going into cybersecurity profession"
birth_year = 1999
current_year = 2026
# Calculate Age
age = current_year - birth_year
# Print introduction
# Print top border
print("=" * 25)
# Print bio sentence
print("My name is", name, "and I am", age, "years old.", goal)
# Print bottom border
print("=" * 25)
# Out:
# ...
# My name is Tristan Thomsen and I am 27 years old. I am going into cybersecurity profession
# ...
