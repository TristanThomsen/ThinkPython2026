# %% [markdown]
# <a href="https://colab.research.google.com/github/TristanThomsen/ThinkPython2026/blob/main/Library_py/Library_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Library.py


#### IMPORT STATEMENTS ####
        # None
#### CLASS DEFINITIONS ####
class Book:
    def __init__(self, title, author):
  # Name of Book

  # Name of the Author

  # Variable to know if it can be checked out or not

def __str__(self):
  # Return the information all together in a string


#### PROGRAM LOGIC ####

def checkout(self):
# Checkout Method, to determine if its checked out or available.
