# %% [markdown]
# <a href="https://colab.research.google.com/github/TristanThomsen/ThinkPython2026/blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
  print(name)
  print(age)
  print(goal)
# 2. Inside the function, use string multiplication (*) for a border line.
def border_line():
  print( "*" * 30)
# 3. Print the bio details using the parameter names.
print("Name: Alex , Age: 50 , Goal: Learning Guitar")


# PROGRAM LOGIC
# 1. Call print_bio using my own info.
border_line()
print_bio("Name: Tristan", "Age: 26", "Goal: Cybersecurity Analyst")
border_line()
# 2. Call print_bio using [Name of Famouse Person]
# 3. Call print_bio using [Name of Fictional Character]
# Out:
# Name: Alex , Age: 50 , Goal: Learning Guitar
# ******************************
# Name: Tristan
# Age: 26
# Goal: Cybersecurity Analyst
# ******************************
